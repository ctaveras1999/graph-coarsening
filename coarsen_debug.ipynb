# %%
import sys
sys.path.insert(0, './core')
sys.path.insert(0, '')
# from DataTools import MeasureNetwork
from tqdm import tqdm
from CoarsenTools import coarsen_data, parse_dataset
import os
import torch
import numpy as np

if __name__ == "__main__":
    datasets = ['MSRC_9', 'MUTAG', 'PTC_MR', 'IMDB-BINARY', 'ENZYMES']
    methods =  ["MGC", "SGC", "WGC", "KGPC", "GPC"] # STATIC -- Don't Change!
    dir_prefix = 'coarsened_final'
    coarse_levels = list(np.linspace(0, 1, 21)[-2:0:-1]) 

    cpus = 60
    for dataset_name in datasets[-1:]:
        for method in tqdm([0, 1, 2, 3, 4]):
            base = os.path.join('.', 'dataset') 
            data = parse_dataset(base, dataset_name) 
            coarsen_data(data, dataset_name, method, coarse_levels, cpus, dir_prefix)
# Out:
#   0%|          | 0/5 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 22
#      20 base = os.path.join('.', 'dataset')
#      21 data = parse_dataset(base, dataset_name)
# ---> 22 coarsen_data(data, dataset_name, method, coarse_levels, cpus, dir_prefix)
#
# File ~/Desktop/graph-coarsening/./core/CoarsenTools.py:152, in coarsen_data(data, dataset_name, method, redu_factor, cpus, base_dir)
#     149 method_name = methods[method]
#     151 with multiprocessing.Pool(cpus) as pool:
# --> 152     res = pool.starmap(coarsen_mat, zip(zip(As, Ps, Xs), opts_list)) # change back!
#     154 Acs, Pcs, Xcs, Qs = np.zeros(num_graphs, dtype=object), np.zeros(num_graphs, dtype=object), np.zeros(num_graphs, dtype=object), np.zeros(num_graphs, dtype=object)
#     156 for i, res_i in enumerate(zip(res)):
#
# File ~/miniconda3/envs/graph_series/lib/python3.11/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/miniconda3/envs/graph_series/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/miniconda3/envs/graph_series/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/miniconda3/envs/graph_series/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/miniconda3/envs/graph_series/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
